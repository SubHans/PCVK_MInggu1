# %% [markdown]
# <a href="https://colab.research.google.com/github/SubHans/PCVK_SEM6/blob/main/Modul2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Latihan 1

# %%
from google.colab import drive

# Access Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Pcvk/skysports-nba-sky-live-live-on-sky_4810101.jpg')
plt.imshow(img)

# %% [markdown]
# Latihan 2

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# Latihan 3

# %%
img_gray = cv.imread('/content/drive/MyDrive/Pcvk/skysports-nba-sky-live-live-on-sky_4810101.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Latihan 4

# %%
black_img = np.zeros(shape=(512,512,3),dtype = np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Tugas

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Pcvk/2021_02_19_110706_1613721093._large.jpg')
plt.imshow(img)

# %% [markdown]
# Tugas 2

# %%
# Red-Green
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
# Green-Blue
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %% [markdown]
# Tugas 3

# %%
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %% [markdown]
# Tugas 4

# %%
plt.imshow(img[5:30])

# %% [markdown]
# Tugas 5

# %%
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(300,300), pt2=(100,100), color=(123,157,200), thickness=10)
cv.rectangle(img_ktk, pt1=(550,100), pt2=(500,200), color=(147,222,214),thickness=10)
cv.rectangle(img_ktk, pt1=(400,400), pt2=(600,300), color=(64,255,123),thickness=10)
cv.rectangle(img_ktk, pt1=(100,500), pt2=(300,400), color=(255,247,175),thickness=10)
cv.rectangle(img_ktk, pt1=(900,650), pt2=(600,500), color=(156,100,200),thickness=10)
plt.imshow(img_ktk)

# %% [markdown]
# Tugas 6

# %%
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %% [markdown]
# Tugas 7

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Pcvk/DSC05140.JPG')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
cv.rectangle(img,pt1=(3300,1000),pt2=(4000,1900),color=(0,0,255),thickness=30)
plt.imshow(img)

# %%
cv.circle(img,center=(3650,1400),radius=350,color=(255,0,0),thickness=25)
plt.imshow(img)

# %% [markdown]
# Tugas 8

# %%
cv.rectangle(img,pt1=(100,2500),pt2=(1000,3900),color=(0,255,0),thickness=25)
plt.imshow(img)

# %% [markdown]
# Tugas 9

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,text='Subhan Indra',org=(2700,2200),fontFace=font,fontScale=10,color=(255,255,255),thickness=25,lineType=cv.LINE_AA)
plt.imshow(img)
